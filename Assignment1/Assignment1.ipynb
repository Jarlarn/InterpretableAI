# %% [markdown]
# ## LLM Usage
# I have used LLMs in order to ask questions, have a better understanding, getting access to relevant documentation in order to solve the assignment and to get improvement ideas for the code.
# ### Personal details
# Full Name: Jarl Dang <br>
# Civic Number: 20010827-9191

# %% [markdown]
# ## Dependencies
# In order to run the applicaion you will need to install certain libraries
#
# > pip install numpy matplotlib scipy tensorflow

# %% [markdown]
# ## Import the required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# %% [markdown]
# ## Task 1: Read and visualize the time series data
#
# In order to read the data we simply load it using np.loadtxt. Then to visualise it we simply plot the data with plt.

# %%
training_data = np.loadtxt("A1_training.txt")
validation_data = np.loadtxt("A1_validation.txt")
test_data = np.loadtxt("A1_test.txt")

# %%
plt.figure(figsize=(14, 5))
plt.subplot(1, 3, 1)
plt.plot(training_data)
plt.title("Training Data")
plt.xlabel("Time step")
plt.ylabel("Value")

plt.subplot(1, 3, 2)
plt.plot(validation_data, color="green")
plt.title("Validation Data")
plt.xlabel("Time step")
plt.ylabel("Value")

plt.subplot(1, 3, 3)
plt.plot(test_data, color="red")
plt.title("Test Data")
plt.xlabel("Time step")
plt.ylabel("Value")

plt.tight_layout()
plt.savefig("task1_time_series.png")
plt.show()

# %% [markdown]
# ## Arma model
# We then create a function in order to define the arma model. This follows directly from the definition of an arma model. The ARMA model is created by combining the AR part and the MA part. In order for the fitting to stay unbiased we set the inital steps to mu, the standard mean value. This will later be used in order to calculate the loss function.

# %%
def arma_model(phi, theta, mu, data):
    """
    General ARMA(p, q) model.
    Returns predictions (y_hat) and residuals (eps).
    """
    p = len(phi)
    q = len(theta)
    n = len(data)
    eps = np.zeros(n)
    y_hat = np.zeros(n)

    for t in range(max(p, q)):
        y_hat[t] = 0
        eps[t] = 0

    for t in range(max(p, q), n):
        ar_part = 0.0
        for i in range(p):
            ar_part = ar_part + phi[i] * data[t - i - 1]

        ma_part = 0.0
        for j in range(q):
            ma_part = ma_part + theta[j] * eps[t - j - 1]

        y_hat[t] = mu + ar_part + ma_part
        eps[t] = data[t] - y_hat[t]

    return y_hat, eps

# %% [markdown]
# ## Loss function
# After creating the ARMA model we need a function to calculate the loss in order to fit the model. This loss function is calculated according to theory and is taken as the negative log-likelihood for a Gaussian error model, which is the standard loss function for ARMA models.

# %%
def arma_loss(params, data, p, q, mu, sigma):
    """
    Negative log-likelihood loss for ARMA(p, q).
    params: [phi_1, ..., phi_p, theta_1, ..., theta_q]
    """
    phi = params[:p]
    theta = params[p : p + q]

    y_hat, eps = arma_model(phi, theta, mu, data)

    n = len(data)
    loss = 0.0
    for t in range(max(p,q),n):
        loss = loss + np.log(sigma) + (eps[t] ** 2) / (2 * sigma**2)
    return loss

# %% [markdown]
# ## Prediction Function
# We then need to create a function in order to actually predict one step ahead. This function is exactly the same as the arma model, but we change the values for the inital predictions. Instead of using the mean we use the real data, and instead of using the residuals we set it to zero since the true errors are unknown at prediction time.

# %%
def arma_predict_one_step(phi, theta, mu, data):
    """
    One-step-ahead prediction on data using fitted ARMA parameters.
    For each t, predict X_t using actual past values and past residuals.
    """
    p = len(phi)
    q = len(theta)
    n = len(data)
    eps = np.zeros(n)
    y_hat = np.zeros(n)

    for t in range(max(p, q)):
        y_hat[t] = 0
        eps[t] = 0

    for t in range(max(p, q), n):
        ar_part = 0.0
        for i in range(p):
            ar_part = ar_part + phi[i] * data[t - i - 1]

        ma_part = 0.0
        for j in range(q):
            ma_part = ma_part + theta[j] * eps[t - j - 1]

        y_hat[t] = mu + ar_part + ma_part
        eps[t] = data[t] - y_hat[t]

    return y_hat

# %% [markdown]
# # Task 2
#
# ## Fitting the ARMA model
# Now we run the training in order to actually fit the arma model. We use the minimize function in order to minimize the loss function with p and q as variables using the Nelder-Mead method. This allows us to find the best values of Phi and Theta which minimizes the loss function.
#
# In order to find the best parameters of P and Q we do a gridsearch, meaning we do two for loops in order to try every combination where P and Q can take values from 1 to 4.
#
# In the end we print the best configuration that yielded the lowest RMSE
# > The best configuration found by the program was ARMA(2,4) and yielded the following results:
# > <br> Best (p, q): (2, 4)
# > <br> RMSE: 1.7700185565719335
# > <br> Best phi: [-0.08567026  0.19421197]
# > <br> Best theta: [1.37749712 1.35641255 1.00323093 0.43720808]

# %%
best_rmse = float("inf")
best_p = None
best_q = None
best_phi = None
best_theta = None
best_pred = None

mu = np.mean(training_data)
sigma = np.std(training_data)

for p in range(1, 5):
    for q in range(1, 5):
        init_params = np.zeros(p + q)
        try:
            result = minimize(
                arma_loss,
                init_params,
                args=(training_data, p, q, mu, sigma),
                method="Nelder-Mead",
                tol=1e-4,
            )
            phi = result.x[:p]
            theta = result.x[p : p + q]
            pred = arma_predict_one_step(phi, theta, mu, validation_data)
            warmup = max(p, q)
            rmse = np.sqrt(np.mean((validation_data[warmup:] - pred[warmup:]) ** 2))
            print(f"p={p}, q={q}, RMSE={rmse}")
            if rmse < best_rmse:
                best_rmse = rmse
                best_p = p
                best_q = q
                best_phi = phi
                best_theta = theta
                best_pred = pred
        except Exception as e:
            print(f"Failed for p={p}, q={q}: {e}")

print(f"\nBest (p, q): ({best_p}, {best_q}) with RMSE: {best_rmse}")
print("Best phi:", best_phi)
print("Best theta:", best_theta)
# Out:
# C:\Users\Jenny\AppData\Local\Temp\ipykernel_26932\884493861.py:23: RuntimeWarning: overflow encountered in scalar multiply
#   ma_part = ma_part + theta[j] * eps[t - j - 1]
# C:\Users\Jenny\AppData\Local\Temp\ipykernel_26932\3958879777.py:14: RuntimeWarning: overflow encountered in scalar power
#   loss = loss + np.log(sigma) + (eps[t] ** 2) / (2 * sigma**2)
# p=1, q=1, RMSE=4.4022755177376744
# p=1, q=2, RMSE=2.811288129122429
# C:\Users\Jenny\AppData\Local\Temp\ipykernel_26932\884493861.py:23: RuntimeWarning: invalid value encountered in scalar add
#   ma_part = ma_part + theta[j] * eps[t - j - 1]
# p=1, q=3, RMSE=2.0514155237562877
# p=1, q=4, RMSE=1.624941890220938
# p=2, q=1, RMSE=4.3112977214693755
# p=2, q=2, RMSE=2.6644753203569618
# p=2, q=3, RMSE=1.9182443967361187
# p=2, q=4, RMSE=1.8428444664758585
# p=3, q=1, RMSE=3.970789933051672
# p=3, q=2, RMSE=2.6485060763291206
# p=3, q=3, RMSE=1.8647899506929837
# p=3, q=4, RMSE=1.903800064686795
# p=4, q=1, RMSE=3.8455658369297714
# p=4, q=2, RMSE=2.652156597670429
# p=4, q=3, RMSE=2.323563588097268
# p=4, q=4, RMSE=2.042002844210291
#
# Best (p, q): (1, 4) with RMSE: 1.624941890220938
# Best phi: [0.07947914]
# Best theta: [1.62722504 1.81415505 1.35238607 0.59836671]

# %% [markdown]
# ## Plotting the best result
# We run the ARMA prediction with the best configuration gotten above versus the test data. The red represents the predictions made by the ARMA model and the blue is the test data.

# %%
test_pred = arma_predict_one_step(best_phi, best_theta, mu, test_data)

plt.figure(figsize=(12, 5))
plt.plot(test_data, label="Test Data", color="blue")
plt.plot(
    test_pred, label=f"Best ARMA({best_p},{best_q}) Fit", color="red", linestyle="--"
)
plt.title(f"Test Data vs Best ARMA({best_p},{best_q}) Fit  |  RMSE = {best_rmse:.4f}")
plt.xlabel("Time step")
plt.ylabel("Value")
plt.legend()
plt.tight_layout()
plt.savefig("task2_arma_best_fit.png")
plt.show()

# %% [markdown]
# # Task 3
#
# ## Finding suitable P and Q values by doing ACF and PACF
# Here we implement the functions needed to calculate the ACF and PACF, the implementations are simply as the formulas are defined. Here I decided that a reasonable amount of lags to calculate is twenty as adviced in lectures.

# %%
def acf(x, nlags):
    x = list(x)
    n = len(x)
    mean = sum(x) / n
    acf_vals = []
    for k in range(nlags + 1):
        numerator = 0.0
        denominator = 0.0
        for t in range(k, n):
            numerator += (x[t] - mean) * (x[t - k] - mean)
        for t in range(n):
            denominator += (x[t] - mean) ** 2
        acf_vals.append(numerator / denominator)
    return acf_vals


def pacf(x, nlags):
    x = np.array(x)
    pacf_vals = [1.0]
    for k in range(1, nlags + 1):
        X = []
        y = []
        for t in range(k, len(x)):
            X.append([x[t - i - 1] for i in range(k)])
            y.append(x[t])
        X = np.array(X)
        y = np.array(y)
        if len(X) > 0:
            coef = np.linalg.lstsq(X, y, rcond=None)[0]
            pacf_vals.append(coef[-1])
        else:
            pacf_vals.append(0.0)
    return pacf_vals


nlags = 20
acf_vals = acf(training_data, nlags)
pacf_vals = pacf(training_data, nlags)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.stem(range(nlags + 1), acf_vals)
plt.title("ACF (Training Data)")
plt.xlabel("Lag")
plt.ylabel("Autocorrelation")

plt.subplot(1, 2, 2)
plt.stem(range(nlags + 1), pacf_vals)
plt.title("PACF (Training Data)")
plt.xlabel("Lag")
plt.ylabel("Partial Autocorrelation")

plt.tight_layout()
plt.savefig("acf_pacf_training.png")
plt.show()

# %% [markdown]
# By analysing these figures we can assume that a q value of around 4 seems reasonable since the magnitude there after seems to decrease. Although it is harder to determine what a good value for p would be since the ACF figure does not clearly indicate a clear cutoff or sharp drop. This suggests that the AR component may not be as dominant or that a lower p value is good enough. It was therefore important that we did the grid search earlier in order to find the best configurations.

# %% [markdown]
# # Task 4
#
# ## LSTM
# The LSTM implementation is farily straight forward and follows from the documentation written by Tensorflow.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from tensorflow.keras.models import Sequential
#       4 from tensorflow.keras.layers import LSTM, Dense
#       5 from tensorflow.keras.optimizers import Adam
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# ModuleNotFoundError: No module named 'tensorflow.python'

# %% [markdown]
# ## Formatting the data
#
# The LSTM network requires the data to be formatted a certain way. It expects an input shape in the form of (samples, timesteps, features). In order to predict the next value we will use a sliding window of size "window_size". This is defined as the number of past values used to predict the next one. It will be set to 10 as adviced on lectures.

# %%
training_data = np.loadtxt("A1_training.txt")
validation_data = np.loadtxt("A1_validation.txt")
test_data = np.loadtxt("A1_test.txt")



def create_sequences(data, window_size):
    X = []
    y = []
    for t in range(window_size, len(data)):
        X.append(data[t - window_size : t])
        y.append(data[t])
    X = np.array(X)
    y = np.array(y)
    X = X.reshape(X.shape[0], X.shape[1], 1)
    return X, y


window_size = 10

X_train, y_train = create_sequences(training_data, window_size)
X_val, y_val = create_sequences(validation_data, window_size)
X_test, y_test = create_sequences(test_data, window_size)

# %% [markdown]
# ## Building and training
# In this step we build and train the LSTM model. We save the best model based on the validation loss and we also stop the training early if we stop seeing improvements for 10 generations in a row.
#
# For the optimisation we use the Adam method with the mean squared error for loss calculation.

# %%
def build_and_train(num_units, window_size, X_train, y_train, X_val, y_val):
    model = Sequential()
    model.add(LSTM(num_units, activation="tanh", input_shape=(window_size, 1)))
    model.add(Dense(1))

    model.compile(optimizer=Adam(), loss="mse")

    checkpoint = ModelCheckpoint(
        f"best_lstm_{num_units}.keras",
        monitor="val_loss",
        save_best_only=True,
        verbose=0,
    )

    early_stop = EarlyStopping(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True,
        verbose=1,
    )

    history = model.fit(
        X_train,
        y_train,
        epochs=100,
        batch_size=64,
        validation_data=(X_val, y_val),
        callbacks=[checkpoint, early_stop],
        verbose=1,
    )

    return model, history

# %% [markdown]
# ## Finding the best configuration
# In order to find the best amount of LSTM units we simply try several options and pick the one with the lowest validation error.
# > The best result was with 16 LSTM units with an rmse of 5053

# %%
unit_options = [8, 16, 32, 64]


best_val_rmse = float("inf")
best_units = None
best_model = None
best_pred = None

for num_units in unit_options:
    print(f"\n--- Training LSTM with {num_units} units ---")
    model, history = build_and_train(
        num_units, window_size, X_train, y_train, X_val, y_val
    )

    # Predict on validation set
    val_pred = model.predict(X_val).flatten()
    val_rmse = np.sqrt(np.mean((y_val - val_pred) ** 2))
    print(f"LSTM ({num_units} units) - Validation RMSE: {val_rmse:.4f}")

    if val_rmse < best_val_rmse:
        best_val_rmse = val_rmse
        best_units = num_units
        best_model = model

# After selecting the best model, evaluate on test set
best_pred = best_model.predict(X_test).flatten()
test_rmse = np.sqrt(np.mean((y_test - best_pred) ** 2))
print(
    f"\nBest LSTM: {best_units} units with Validation RMSE: {best_val_rmse:.4f} and Test RMSE: {test_rmse:.4f}"
)
# Out:
# --- Training LSTM with 8 units ---
# Epoch 1/100
# c:\Users\jarld\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 544.3176 - val_loss: 484.4592
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 461.8334 - val_loss: 409.4293
# Epoch 3/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 387.8537 - val_loss: 361.0888
# Epoch 4/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 340.0954 - val_loss: 320.5945
# Epoch 5/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 304.0323 - val_loss: 287.8781
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 273.5085 - val_loss: 259.4192
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 246.7262 - val_loss: 234.2277
# Epoch 8/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 222.7784 - val_loss: 211.5514
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 201.2130 - val_loss: 191.1195
# Epoch 10/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 181.8470 - val_loss: 172.7563
# Epoch 11/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 164.3650 - val_loss: 156.1904
# Epoch 12/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 148.6872 - val_loss: 141.3337
# Epoch 13/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 134.4881 - val_loss: 127.8617
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 121.6219 - val_loss: 115.6937
# Epoch 15/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 110.0323 - val_loss: 104.6668
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 99.5412 - val_loss: 94.7388
# Epoch 17/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 89.9974 - val_loss: 85.6969
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 81.3302 - val_loss: 77.4715
# Epoch 19/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 73.4448 - val_loss: 69.9948
# Epoch 20/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 66.3074 - val_loss: 63.2121
# Epoch 21/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 59.7925 - val_loss: 57.0054
# Epoch 22/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 53.8764 - val_loss: 51.4149
# Epoch 23/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48.4782 - val_loss: 46.2583
# Epoch 24/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43.6032 - val_loss: 41.5781
# Epoch 25/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.1788 - val_loss: 37.4115
# Epoch 26/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 35.1654 - val_loss: 33.4989
# Epoch 27/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31.5047 - val_loss: 30.0248
# Epoch 28/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28.2129 - val_loss: 26.8421
# Epoch 29/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 25.2242 - val_loss: 23.9613
# Epoch 30/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.8946 - val_loss: 18.4840
# Epoch 31/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.3818 - val_loss: 14.8227
# Epoch 32/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.5673 - val_loss: 12.4720
# Epoch 33/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.5309 - val_loss: 10.6620
# Epoch 34/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8974 - val_loss: 9.1558
# Epoch 35/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5437 - val_loss: 8.0231
# Epoch 36/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.4333 - val_loss: 6.9183
# Epoch 37/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.4523 - val_loss: 6.0002
# Epoch 38/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.6472 - val_loss: 5.2545
# Epoch 39/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.9551 - val_loss: 4.6050
# Epoch 40/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.3594 - val_loss: 4.0523
# Epoch 41/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8336 - val_loss: 3.5691
# Epoch 42/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3803 - val_loss: 3.1831
# Epoch 43/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9899 - val_loss: 2.7801
# Epoch 44/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6415 - val_loss: 2.4563
# Epoch 45/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3526 - val_loss: 2.1962
# Epoch 46/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0938 - val_loss: 1.9572
# Epoch 47/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8804 - val_loss: 1.7643
# Epoch 48/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6913 - val_loss: 1.5965
# Epoch 49/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5347 - val_loss: 1.4684
# Epoch 50/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3955 - val_loss: 1.3338
# Epoch 51/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2783 - val_loss: 1.2245
# Epoch 52/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1813 - val_loss: 1.1269
# Epoch 53/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0808 - val_loss: 1.0755
# Epoch 54/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9969 - val_loss: 0.9717
# Epoch 55/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9307 - val_loss: 0.8934
# Epoch 56/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8628 - val_loss: 0.8588
# Epoch 57/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8077 - val_loss: 0.8007
# Epoch 58/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7496 - val_loss: 0.7373
# Epoch 59/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7046 - val_loss: 0.7344
# Epoch 60/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6714 - val_loss: 0.6307
# Epoch 61/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6217 - val_loss: 0.6845
# Epoch 62/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5906 - val_loss: 0.5571
# Epoch 63/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5500 - val_loss: 0.5241
# Epoch 64/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5253 - val_loss: 0.4977
# Epoch 65/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4978 - val_loss: 0.4829
# Epoch 66/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4783 - val_loss: 0.4644
# Epoch 67/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4567 - val_loss: 0.4519
# Epoch 68/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4372 - val_loss: 0.4295
# Epoch 69/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4306 - val_loss: 0.4046
# Epoch 70/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4125 - val_loss: 0.4250
# Epoch 71/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3966 - val_loss: 0.3908
# Epoch 72/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3856 - val_loss: 0.3883
# Epoch 73/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3794 - val_loss: 0.5049
# Epoch 74/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3731 - val_loss: 0.3814
# Epoch 75/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3672 - val_loss: 0.3492
# Epoch 76/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3587 - val_loss: 0.3874
# Epoch 77/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3515 - val_loss: 0.3974
# Epoch 78/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3490 - val_loss: 0.3601
# Epoch 79/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3440 - val_loss: 0.3425
# Epoch 80/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3425 - val_loss: 0.3369
# Epoch 81/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3334 - val_loss: 0.3462
# Epoch 82/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3336 - val_loss: 0.3192
# Epoch 83/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3354 - val_loss: 0.3470
# Epoch 84/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3255 - val_loss: 0.3078
# Epoch 85/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3243 - val_loss: 0.3142
# Epoch 86/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3194 - val_loss: 0.2984
# Epoch 87/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3196 - val_loss: 0.3536
# Epoch 88/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3247 - val_loss: 0.2948
# Epoch 89/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3145 - val_loss: 0.3126
# Epoch 90/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3175 - val_loss: 0.2970
# Epoch 91/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3135 - val_loss: 0.2978
# Epoch 92/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3142 - val_loss: 0.2934
# Epoch 93/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3090 - val_loss: 0.3076
# Epoch 94/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3130 - val_loss: 0.3222
# Epoch 95/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3080 - val_loss: 0.2889
# Epoch 96/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2999 - val_loss: 0.3063
# Epoch 97/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.2889
# Epoch 98/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3050 - val_loss: 0.2956
# Epoch 99/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3025 - val_loss: 0.2996
# Epoch 100/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2993 - val_loss: 0.2776
# Restoring model weights from the end of the best epoch: 100.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# LSTM (8 units) - Validation RMSE: 0.5269
#
# --- Training LSTM with 16 units ---
# Epoch 1/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 570.9869 - val_loss: 452.5362
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 360.7188 - val_loss: 271.4032
# Epoch 3/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 233.9664 - val_loss: 201.5658
# Epoch 4/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 177.0358 - val_loss: 154.7973
# Epoch 5/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 136.5637 - val_loss: 119.9240
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 106.2828 - val_loss: 93.9352
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 83.4756 - val_loss: 74.1697
# Epoch 8/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 65.9857 - val_loss: 58.8932
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 52.5292 - val_loss: 47.0441
# Epoch 10/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 41.9839 - val_loss: 37.6996
# Epoch 11/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.6965 - val_loss: 30.3261
# Epoch 12/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 27.1124 - val_loss: 24.4404
# Epoch 13/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.8788 - val_loss: 19.7480
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 17.7428 - val_loss: 15.9853
# Epoch 15/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.3843 - val_loss: 13.0013
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 11.6881 - val_loss: 10.5833
# Epoch 17/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5611 - val_loss: 8.6767
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8610 - val_loss: 7.0963
# Epoch 19/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4980 - val_loss: 5.8696
# Epoch 20/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3715 - val_loss: 4.8760
# Epoch 21/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4648 - val_loss: 4.0214
# Epoch 22/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7113 - val_loss: 3.3615
# Epoch 23/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.1098 - val_loss: 2.8621
# Epoch 24/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6390 - val_loss: 2.4307
# Epoch 25/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.2549 - val_loss: 2.0774
# Epoch 26/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.9405 - val_loss: 1.8408
# Epoch 27/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6931 - val_loss: 1.5995
# Epoch 28/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.4928 - val_loss: 1.3976
# Epoch 29/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.3232 - val_loss: 1.2696
# Epoch 30/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1884 - val_loss: 1.1318
# Epoch 31/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0647 - val_loss: 1.0116
# Epoch 32/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9594 - val_loss: 0.9328
# Epoch 33/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8674 - val_loss: 0.8367
# Epoch 34/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7986 - val_loss: 0.7734
# Epoch 35/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7395 - val_loss: 0.7452
# Epoch 36/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6888 - val_loss: 0.6818
# Epoch 37/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6295 - val_loss: 0.6187
# Epoch 38/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5871 - val_loss: 0.6012
# Epoch 39/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5560 - val_loss: 0.5488
# Epoch 40/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5236 - val_loss: 0.5221
# Epoch 41/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4950 - val_loss: 0.4770
# Epoch 42/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4713 - val_loss: 0.4650
# Epoch 43/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4444 - val_loss: 0.4309
# Epoch 44/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4310 - val_loss: 0.4579
# Epoch 45/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4147 - val_loss: 0.4042
# Epoch 46/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3973 - val_loss: 0.4285
# Epoch 47/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3808 - val_loss: 0.3701
# Epoch 48/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3666 - val_loss: 0.3674
# Epoch 49/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3600 - val_loss: 0.3637
# Epoch 50/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3575 - val_loss: 0.3815
# Epoch 51/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3518 - val_loss: 0.3252
# Epoch 52/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3410 - val_loss: 0.3473
# Epoch 53/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3392 - val_loss: 0.3383
# Epoch 54/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3316 - val_loss: 0.3217
# Epoch 55/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3256 - val_loss: 0.3194
# Epoch 56/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3283 - val_loss: 0.3051
# Epoch 57/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3195 - val_loss: 0.3043
# Epoch 58/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3145 - val_loss: 0.2966
# Epoch 59/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3145 - val_loss: 0.3300
# Epoch 60/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3174 - val_loss: 0.2950
# Epoch 61/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3085 - val_loss: 0.2956
# Epoch 62/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3060 - val_loss: 0.3041
# Epoch 63/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3049 - val_loss: 0.2993
# Epoch 64/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3029 - val_loss: 0.2938
# Epoch 65/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2956 - val_loss: 0.3039
# Epoch 66/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2992 - val_loss: 0.2980
# Epoch 67/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2992 - val_loss: 0.3237
# Epoch 68/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2962 - val_loss: 0.2800
# Epoch 69/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2904 - val_loss: 0.3065
# Epoch 70/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2921 - val_loss: 0.2710
# Epoch 71/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2879 - val_loss: 0.2829
# Epoch 72/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2897 - val_loss: 0.2729
# Epoch 73/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2866 - val_loss: 0.2774
# Epoch 74/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2931 - val_loss: 0.2692
# Epoch 75/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2877 - val_loss: 0.2731
# Epoch 76/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2842 - val_loss: 0.2650
# Epoch 77/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2922 - val_loss: 0.2691
# Epoch 78/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2857 - val_loss: 0.2747
# Epoch 79/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2844 - val_loss: 0.2713
# Epoch 80/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2856 - val_loss: 0.2874
# Epoch 81/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2805 - val_loss: 0.2707
# Epoch 82/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2805 - val_loss: 0.2751
# Epoch 83/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2834 - val_loss: 0.2681
# Epoch 84/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2895 - val_loss: 0.2627
# Epoch 85/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2808 - val_loss: 0.2977
# Epoch 86/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2903 - val_loss: 0.3019
# Epoch 87/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2831 - val_loss: 0.2834
# Epoch 88/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2884 - val_loss: 0.2785
# Epoch 89/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2843 - val_loss: 0.2930
# Epoch 90/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2808 - val_loss: 0.3197
# Epoch 91/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2819 - val_loss: 0.3618
# Epoch 92/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2910 - val_loss: 0.2708
# Epoch 93/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2876 - val_loss: 0.2639
# Epoch 94/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2790 - val_loss: 0.2556
# Epoch 95/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2746 - val_loss: 0.2589
# Epoch 96/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2819 - val_loss: 0.2767
# Epoch 97/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2764 - val_loss: 0.2632
# Epoch 98/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2822 - val_loss: 0.2538
# Epoch 99/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2778 - val_loss: 0.2624
# Epoch 100/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2773 - val_loss: 0.2651
# Restoring model weights from the end of the best epoch: 98.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# LSTM (16 units) - Validation RMSE: 0.5038
#
# --- Training LSTM with 32 units ---
# Epoch 1/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 404.3708 - val_loss: 264.1852
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 200.0253 - val_loss: 153.4270
# Epoch 3/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 123.4451 - val_loss: 97.4396
# Epoch 4/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 79.3394 - val_loss: 64.0396
# Epoch 5/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 52.6202 - val_loss: 43.1600
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 35.7000 - val_loss: 29.5547
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 24.7248 - val_loss: 20.7021
# Epoch 8/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.4520 - val_loss: 14.7164
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.5555 - val_loss: 10.6615
# Epoch 10/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1698 - val_loss: 7.8440
# Epoch 11/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8261 - val_loss: 5.8732
# Epoch 12/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1635 - val_loss: 4.4732
# Epoch 13/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9664 - val_loss: 3.4735
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0884 - val_loss: 2.7726
# Epoch 15/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4548 - val_loss: 2.2014
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.9781 - val_loss: 1.7937
# Epoch 17/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6370 - val_loss: 1.4704
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3607 - val_loss: 1.2953
# Epoch 19/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1603 - val_loss: 1.0847
# Epoch 20/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0033 - val_loss: 0.9482
# Epoch 21/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8802 - val_loss: 0.8305
# Epoch 22/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7812 - val_loss: 0.7481
# Epoch 23/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7078 - val_loss: 0.6870
# Epoch 24/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6341 - val_loss: 0.6321
# Epoch 25/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5831 - val_loss: 0.5479
# Epoch 26/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5336 - val_loss: 0.5340
# Epoch 27/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4966 - val_loss: 0.4824
# Epoch 28/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4328 - val_loss: 0.3985
# Epoch 29/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4045 - val_loss: 0.3835
# Epoch 30/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3896 - val_loss: 0.3686
# Epoch 31/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3727 - val_loss: 0.3648
# Epoch 32/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3622 - val_loss: 0.3459
# Epoch 33/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3500 - val_loss: 0.3472
# Epoch 34/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3461 - val_loss: 0.3500
# Epoch 35/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3414 - val_loss: 0.3297
# Epoch 36/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3374 - val_loss: 0.3281
# Epoch 37/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3293 - val_loss: 0.3219
# Epoch 38/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3277 - val_loss: 0.3322
# Epoch 39/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3237 - val_loss: 0.3362
# Epoch 40/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3174 - val_loss: 0.3246
# Epoch 41/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3193 - val_loss: 0.3030
# Epoch 42/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3136 - val_loss: 0.3296
# Epoch 43/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3116 - val_loss: 0.2929
# Epoch 44/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3074 - val_loss: 0.3077
# Epoch 45/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3052 - val_loss: 0.3120
# Epoch 46/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3056 - val_loss: 0.3250
# Epoch 47/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3097 - val_loss: 0.3048
# Epoch 48/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2962 - val_loss: 0.3189
# Epoch 49/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3009 - val_loss: 0.2997
# Epoch 50/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3079 - val_loss: 0.3023
# Epoch 51/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2970 - val_loss: 0.2893
# Epoch 52/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3074 - val_loss: 0.2799
# Epoch 53/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2861 - val_loss: 0.3010
# Epoch 54/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2992 - val_loss: 0.3004
# Epoch 55/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2905 - val_loss: 0.2968
# Epoch 56/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3076 - val_loss: 0.2958
# Epoch 57/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2965 - val_loss: 0.2923
# Epoch 58/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2946 - val_loss: 0.3020
# Epoch 59/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2900 - val_loss: 0.2806
# Epoch 60/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2878 - val_loss: 0.2782
# Epoch 61/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2862 - val_loss: 0.2695
# Epoch 62/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2899 - val_loss: 0.2706
# Epoch 63/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2897 - val_loss: 0.2852
# Epoch 64/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2939 - val_loss: 0.2699
# Epoch 65/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2851 - val_loss: 0.2684
# Epoch 66/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2911 - val_loss: 0.2942
# Epoch 67/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2970 - val_loss: 0.3369
# Epoch 68/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2903 - val_loss: 0.2657
# Epoch 69/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2850 - val_loss: 0.2659
# Epoch 70/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2860 - val_loss: 0.2617
# Epoch 71/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2847 - val_loss: 0.2853
# Epoch 72/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2895 - val_loss: 0.2805
# Epoch 73/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2833 - val_loss: 0.2677
# Epoch 74/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2878 - val_loss: 0.2869
# Epoch 75/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2869 - val_loss: 0.2696
# Epoch 76/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2799 - val_loss: 0.2725
# Epoch 77/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2859 - val_loss: 0.2730
# Epoch 78/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2822 - val_loss: 0.2747
# Epoch 79/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2814 - val_loss: 0.2627
# Epoch 80/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2782 - val_loss: 0.2626
# Epoch 80: early stopping
# Restoring model weights from the end of the best epoch: 70.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# LSTM (32 units) - Validation RMSE: 0.5115
#
# --- Training LSTM with 64 units ---
# Epoch 1/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 330.9698 - val_loss: 130.7394
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 81.0535 - val_loss: 47.2472
# Epoch 3/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 31.7600 - val_loss: 20.7414
# Epoch 4/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.7492 - val_loss: 10.2645
# Epoch 5/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.7072 - val_loss: 5.9203
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.4490 - val_loss: 3.4490
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.7878 - val_loss: 2.2015
# Epoch 8/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.8611 - val_loss: 1.6050
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.3258 - val_loss: 1.1450
# Epoch 10/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0121 - val_loss: 0.9108
# Epoch 11/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8284 - val_loss: 0.7580
# Epoch 12/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6810 - val_loss: 0.6528
# Epoch 13/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5864 - val_loss: 0.5624
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5217 - val_loss: 0.4831
# Epoch 15/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4758 - val_loss: 0.4577
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4383 - val_loss: 0.4377
# Epoch 17/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4128 - val_loss: 0.4466
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3942 - val_loss: 0.3800
# Epoch 19/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3743 - val_loss: 0.3547
# Epoch 20/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3578 - val_loss: 0.3936
# Epoch 21/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3532 - val_loss: 0.3993
# Epoch 22/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3464 - val_loss: 0.3500
# Epoch 23/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3303 - val_loss: 0.3390
# Epoch 24/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3352 - val_loss: 0.3201
# Epoch 25/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3266 - val_loss: 0.3117
# Epoch 26/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3220 - val_loss: 0.3047
# Epoch 27/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3213 - val_loss: 0.2975
# Epoch 28/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3246 - val_loss: 0.3019
# Epoch 29/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3213 - val_loss: 0.3532
# Epoch 30/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3228 - val_loss: 0.3057
# Epoch 31/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3105 - val_loss: 0.3036
# Epoch 32/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3053 - val_loss: 0.2732
# Epoch 33/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3077 - val_loss: 0.2866
# Epoch 34/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2980 - val_loss: 0.3099
# Epoch 35/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2999 - val_loss: 0.2905
# Epoch 36/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3046 - val_loss: 0.2944
# Epoch 37/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3019 - val_loss: 0.2811
# Epoch 38/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2970 - val_loss: 0.2901
# Epoch 39/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2960 - val_loss: 0.2733
# Epoch 40/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3010 - val_loss: 0.3036
# Epoch 41/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2991 - val_loss: 0.3242
# Epoch 42/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2957 - val_loss: 0.2721
# Epoch 43/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2872 - val_loss: 0.2639
# Epoch 44/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2856 - val_loss: 0.2772
# Epoch 45/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2935 - val_loss: 0.2810
# Epoch 46/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2933 - val_loss: 0.3583
# Epoch 47/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2841 - val_loss: 0.2800
# Epoch 48/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2879 - val_loss: 0.2666
# Epoch 49/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2928 - val_loss: 0.2821
# Epoch 50/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2876 - val_loss: 0.2868
# Epoch 51/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2942 - val_loss: 0.2740
# Epoch 52/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2890 - val_loss: 0.2622
# Epoch 53/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2965 - val_loss: 0.3089
# Epoch 54/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2858 - val_loss: 0.3093
# Epoch 55/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2836 - val_loss: 0.2963
# Epoch 56/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2867 - val_loss: 0.2800
# Epoch 57/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3030 - val_loss: 0.3229
# Epoch 58/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2912 - val_loss: 0.3127
# Epoch 59/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2870 - val_loss: 0.3229
# Epoch 60/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2903 - val_loss: 0.2687
# Epoch 61/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2889 - val_loss: 0.2657
# Epoch 62/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2839 - val_loss: 0.3067
# Epoch 62: early stopping
# Restoring model weights from the end of the best epoch: 52.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# LSTM (64 units) - Validation RMSE: 0.5121
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Best LSTM: 16 units with Validation RMSE: 0.5038 and Test RMSE: 0.5053

# %% [markdown]
# ## Plotting the data
# A similar plot as the one done with the ARMA model is now done but with the LSTM model instead in order to compare the results cleanly.

# %%
plt.figure(figsize=(12, 5))
plt.plot(y_test, label="Test Data", color="blue")
plt.plot(
    best_pred,
    label=f"LSTM ({best_units} units) Prediction",
    color="red",
    linestyle="--",
)
plt.title(f"Test Data vs LSTM ({best_units} units)  |  RMSE = {best_val_rmse:.4f}")
plt.xlabel("Time step")
plt.ylabel("Value")
plt.legend()
plt.tight_layout()
plt.savefig("task_lstm_prediction.png")
plt.show()

# %% [markdown]
# # Task 5 Analysing ARMA(2,4)
#
# ### Analysing AR
# By analysing the p value we can conclude that the 2 most recent timesteps are heavily correlated to the timestep which we are trying to predict. We can also note exactly how strong their influence is by analysing the coefficents(phi) for them. Given the following phi values for the best model:
#
# > <br> Best phi: [-0.08567026  0.19421197]
#
# This indicates that the most recent value (lag 1) has a small negative correlation with the next value, while the second most recent value (lag 2) has a larger positive correlation and plays a more significant role in the prediction.
#
# ### Analysing MA
# We can analyse the MA in the same way. By studying the q value we can conclude that the 4 most recent timesteps are relevant in order to predict the next, since the q values was 4. We can now analyse the PACF graph to see how these timesteps are correlated to the prediction, but more exactly we can inspect the coefficent values since we have calculate those.
#
# > <br> Best theta: [1.37749712 1.35641255 1.00323093 0.43720808]
#
# This tells us that all of the four past timesteps are positvely correlated in order to predict the next, it also tells us that the most recent timestep impacts the most with their magnitude decreasing as the number of lags increase.
#
#
# <br>
# Putting both of these components together we get the final ARMA equation which we use to predict the next value. This is completely interpretable and tells us exactly what terms are important and how they impact the end result.
#
#
# $$
# \begin{align*}
# X_t =\ & \mu \\
#       & - 0.0857 \cdot X_{t-1} \\
#       & + 0.1942 \cdot X_{t-2} \\
#       & + 1.3775 \cdot \epsilon_{t-1} \\
#       & + 1.3564 \cdot \epsilon_{t-2} \\
#       & + 1.0032 \cdot \epsilon_{t-3} \\
#       & + 0.4372 \cdot \epsilon_{t-4}
# \end{align*}
# $$
#
# ### Comparing the models
#
# Strictly comparing the RMSE values of the both models we have RMSE: 1.770 for the ARMA(2,4) model and RMSE:0.5038 for the LSTM version. This is quite a significant performance difference and is definitely worth taking into consideration when choosing a model, although the price in interpretability is steep.
#
# The ARMA model is highly transparent and easy to interpret. It clearly shows the relationship between different time steps and allows us to see exactly how each previous value and residual contributes to the prediction. This makes it straightforward to analyze and understand the model’s behavior, which is a significant advantage in many practical applications and high cost scenarios.
#
#
# On the other hand the LSTM version provides better performance but sacrifices any explainability and transperancy. It also makes it impossible to explain any decisions made by the model and what factors impacted the results, it is therefore more fitted for situations where performance is everything.
